# %% [markdown]
# # Introduction/Business Problem

# %% [markdown]
# In this project, I would like to answer “how accurate is the Foursquare data “. The purpose of this project is provide a recommendation of proxy data collection platform for citizens or government to understand the neighborhood when official data is not available. For instance, how many bicycle shops are in the area of City of Toronto, Canada and which one is the closest to me.

# %% [markdown]
# <h3> Data</h3>

# %% [markdown]
# To get the solution to the above-discussed problem, we will require data that shows the bicycle shops location. Various fields required such as: name of the shop, address or location information such as longitude and latitude, their ratings, and other useful information.

# %% [markdown]
# The data source contains the necessary fields of interest are found from City of Toronto’s Open Data Portal(https://open.toronto.ca/dataset/bicycle-shops/)

# %%
import pandas as pd

# %%
url = "https://ckan0.cf.opendata.inter.prod-toronto.ca/download_resource/e285b0d5-afbc-47e6-b6bf-2f74d9b5a9d7?format=csv&projection=4326"
df = pd.read_csv (url)
#drop unwanted columns
df.drop(['_id','ADDRESS_POINT_ID','ADDRESS_NUMBER','LINEAR_NAME_FULL','MUNICIPALITY','PLACE_NAME','GENERAL_USE_CODE','CENTRELINE_ID','LO_NUM','LO_NUM_SUF','HI_NUM','HI_NUM_SUF','LINEAR_NAME_ID','X','Y','ID','UNIT','OBJECTID'],axis =1,inplace =True)
df
# Out:
#               ADDRESS_FULL POSTAL_CODE     CITY                          WARD  \
# 0            400 King St W     M5V 1K2  Toronto        Spadina-Fort York (10)
# 1           882 College St     M6H 1A3  Toronto                 Davenport (9)
# 2   3731 Lake Shore Blvd W     M8W 1P9  Toronto       Etobicoke-Lakeshore (3)
# 3          1292 Queen St E     M4L 1C4  Toronto         Toronto-Danforth (14)
# 4             2111 Jane St     M3M 1A2  Toronto               York Centre (6)
# 5            29 Barton Ave     M6G 1P2  Toronto      University-Rosedale (11)
# 6          913 Bathurst St     M5R 3G4  Toronto      University-Rosedale (11)
# 7          1882 Queen St E     M4L 1H2  Toronto        Beaches-East York (19)
# 8            835 Albion Rd     M9V 1A3  Toronto           Etobicoke North (1)
# 9        1510 Danforth Ave     M4J 1N4  Toronto         Toronto-Danforth (14)
# 10        563 Spadina Cres     M5S 2J7  Toronto      University-Rosedale (11)
# ...
