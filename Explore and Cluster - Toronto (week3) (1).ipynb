# %%
import requests
import lxml.html as lh
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
# !pip install folium==0.5.0
import folium
print("done")
# Out:
# Collecting folium==0.5.0
#   Downloading https://files.pythonhosted.org/packages/07/37/456fb3699ed23caa0011f8b90d9cad94445eddc656b601e6268090de35f5/folium-0.5.0.tar.gz (79kB)
#      |████████████████████████████████| 81kB 3.9MB/s eta 0:00:01
# Collecting branca (from folium==0.5.0)
#   Downloading https://files.pythonhosted.org/packages/63/36/1c93318e9653f4e414a2e0c3b98fc898b4970e939afeedeee6075dd3b703/branca-0.3.1-py3-none-any.whl
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium==0.5.0) (2.10)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium==0.5.0) (2.21.0)
# Requirement already satisfied: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium==0.5.0) (1.12.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2->folium==0.5.0) (1.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium==0.5.0) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium==0.5.0) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium==0.5.0) (2.8)
# Building wheels for collected packages: folium
#   Building wheel for folium (setup.py) ... done
#   Stored in directory: /home/dsxuser/.cache/pip/wheels/f8/98/ff/954791afc47740d554f0d9e5885fa09dd60c2265d42578e665
# Successfully built folium
# Installing collected packages: branca, folium
# Successfully installed branca-0.3.1 folium-0.5.0
# done

# %% [markdown]
# <b> 1. Extract HTML elements from page to here for preparation, use them to create three lists, each will represent a column in the dataframe</b>

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
page = requests.get(url)
soup = BeautifulSoup(page.content,'html.parser')
tb = soup.find('table',class_="wikitable sortable")
#rows = tb.find_all('tr')
cols= tb.find_all('td')

#====================create first version of each column=================
i=0;
Postcode=[]
Borough=[]
Neighbourhood=[]
while i < len(cols):
    Postcode.append(cols[i])
    Borough.append(cols[i+1])
    Neighbourhood.append(cols[i+2])
    i=i+3

#===========================clean the lists==================================
Postcode_fin=[]
Borough_fin=[]
Neighbourhood_fin=[]
#scan thru the lines in list Postcode, only keep the text in each line 
for code in Postcode:
    Postcode_fin.append(code.get_text())

for code in Borough:
    Borough_fin.append(code.get_text())

for code in Neighbourhood:
    line=code.get_text()
    Neighbourhood_fin.append(line.rsplit('\n')[0])
#================put together the dataframe ================================
dict = {"Postcode":Postcode_fin,"Borough":Borough_fin,"Neighbourhood": Neighbourhood_fin}
df = pd.DataFrame(dict)

# %% [markdown]
# <b> 2. Clean the data </b>

# %%
#=================look for row location and use df.drop to remove them =====================
i=0
idx=[]
for b in df['Borough']=='Not assigned':
    if b==True:
        idx.append(i)
    i=i+1
df.drop(index=idx, axis = 0, inplace = True)

#=================look for "Not assigned " in "Neighbourhood" and assign them as the "Borough" value=====================
i=0
idx=[]
for b in df['Neighbourhood']=="Not assigned":
    if b==True:
        df.replace(df.iloc[i,2],df.iloc[i,1],inplace=True)
    i=i+1

#===============look for duplicated value in column "Postcode"====================
df.sort_values(by=['Postcode'],inplace=True)
df.reset_index(drop=True, inplace = True)
df_fin=pd.DataFrame({'Postcode':[],'Borough':[],'Neighbourhood':[]})
df_fin.reset_index(drop=True,inplace = True)
df_fin.append(df.iloc[[0,1]],sort = False)
#for i in range(1, len(df)):
i =0
b=i+1
while b<len(df['Postcode']): 
    if df.iloc[i,0]==df.iloc[b,0]:
        df.iloc[i,2]=df.iloc[i,2]+", " + df.iloc[b,2]
        df.drop([b,b],inplace =True)
        df.reset_index(drop=True, inplace = True)
    i=i+1
    b=i+1

# %% [markdown]
# <b> Q1: print the number of rows in the df </b>

# %%
df.shape
# Out:
# (139, 3)

# %% [markdown]
# <b> Q2: create df with latitude and longtitude shown </b>

# %%
df_geo = pd.read_csv("https://cocl.us/Geospatial_data")
df_withLL= df.join(df_geo.set_index('Postal Code'),on='Postcode' )
df_withLL
# Out:
#     Postcode       Borough                                      Neighbourhood  \
# 0        M1B   Scarborough                                     Rouge, Malvern
# 1        M1C   Scarborough                             Port Union, Rouge Hill
# 2        M1C   Scarborough                                     Highland Creek
# 3        M1E   Scarborough                             Guildwood, Morningside
# 4        M1E   Scarborough                                          West Hill
# 5        M1G   Scarborough                                             Woburn
# 6        M1H   Scarborough                                          Cedarbrae
# 7        M1J   Scarborough                                Scarborough Village
# 8        M1K   Scarborough                      East Birchmount Park, Ionview
# 9        M1K   Scarborough                                       Kennedy Park
# 10       M1L   Scarborough                              Golden Mile, Oakridge
# 11       M1L   Scarborough                                           Clairlea
# 12       M1M   Scarborough               Cliffcrest, Scarborough Village West
# 13       M1M   Scarborough                                          Cliffside
# 14       M1N   Scarborough                        Cliffside West, Birch Cliff
# 15       M1P   Scarborough                       Wexford Heights, Dorset Park
# 16       M1P   Scarborough                            Scarborough Town Centre
# 17       M1R   Scarborough                                  Maryvale, Wexford
# 18       M1S   Scarborough                                          Agincourt
# 19       M1T   Scarborough                           Sullivan, Clarks Corners
# 20       M1T   Scarborough                                      Tam O'Shanter
# 21       M1V   Scarborough                             Steeles East, Milliken
# 22       M1V   Scarborough                   L'Amoreaux East, Agincourt North
# 23       M1W   Scarborough                                    L'Amoreaux West
# 24       M1X   Scarborough                                        Upper Rouge
# 25       M2H    North York                                  Hillcrest Village
# 26       M2J    North York                               Henry Farm, Fairview
# 27       M2J    North York                                             Oriole
# 28       M2K    North York                                    Bayview Village
# 29       M2L    North York                           Silver Hills, York Mills
# ..       ...           ...                                                ...
# 109      M7Y  East Toronto  Business Reply Mail Processing Centre 969 Eastern
# 110      M8V     Etobicoke                          Mimico South, New Toronto
# 111      M8V     Etobicoke                                  Humber Bay Shores
# 112      M8W     Etobicoke                             Long Branch, Alderwood
# 113      M8X     Etobicoke                    Old Mill North, Montgomery Road
# 114      M8X     Etobicoke                                       The Kingsway
# 115      M8Y     Etobicoke                   Old Mill South, King's Mill Park
# 116      M8Y     Etobicoke                     Humber Bay, The Queensway East
# 117      M8Y     Etobicoke                    Royal York South East, Sunnylea
# 118      M8Y     Etobicoke                Mimico NE, Kingsway Park South East
# 119      M8Z     Etobicoke                Kingsway Park South West, Mimico NW
# 120      M8Z     Etobicoke                 The Queensway West, South of Bloor
# 121      M8Z     Etobicoke                              Royal York South West
# 122      M9A  Queen's Park                                       Queen's Park
# 123      M9B     Etobicoke                        Cloverdale, West Deane Park
# 124      M9B     Etobicoke                     Princess Gardens, Martin Grove
# 125      M9B     Etobicoke                                          Islington
# 126      M9C     Etobicoke                   Old Burnhamthorpe, Markland Wood
# 127      M9C     Etobicoke                        Eringate, Bloordale Gardens
# 128      M9L    North York                                      Humber Summit
# 129      M9M    North York                                   Humberlea, Emery
# 130      M9N          York                                             Weston
# 131      M9P     Etobicoke                                          Westmount
# 132      M9R     Etobicoke                Richview Gardens, Kingsview Village
# 133      M9R     Etobicoke                 St. Phillips, Martin Grove Gardens
# 134      M9V     Etobicoke                   Albion Gardens, Beaumond Heights
# 135      M9V     Etobicoke                              Humbergate, Jamestown
# 136      M9V     Etobicoke                         Mount Olive, South Steeles
# 137      M9V     Etobicoke                           Thistletown, Silverstone
# 138      M9W     Etobicoke                                          Northwest
#
#       Latitude  Longitude
# 0    43.806686 -79.194353
# 1    43.784535 -79.160497
# 2    43.784535 -79.160497
# 3    43.763573 -79.188711
# 4    43.763573 -79.188711
# 5    43.770992 -79.216917
# 6    43.773136 -79.239476
# 7    43.744734 -79.239476
# 8    43.727929 -79.262029
# 9    43.727929 -79.262029
# 10   43.711112 -79.284577
# 11   43.711112 -79.284577
# 12   43.716316 -79.239476
# 13   43.716316 -79.239476
# 14   43.692657 -79.264848
# 15   43.757410 -79.273304
# 16   43.757410 -79.273304
# 17   43.750072 -79.295849
# 18   43.794200 -79.262029
# 19   43.781638 -79.304302
# 20   43.781638 -79.304302
# 21   43.815252 -79.284577
# 22   43.815252 -79.284577
# 23   43.799525 -79.318389
# 24   43.836125 -79.205636
# 25   43.803762 -79.363452
# 26   43.778517 -79.346556
# 27   43.778517 -79.346556
# 28   43.786947 -79.385975
# 29   43.757490 -79.374714
# ..         ...        ...
# 109  43.662744 -79.321558
# 110  43.605647 -79.501321
# 111  43.605647 -79.501321
# 112  43.602414 -79.543484
# 113  43.653654 -79.506944
# 114  43.653654 -79.506944
# 115  43.636258 -79.498509
# 116  43.636258 -79.498509
# 117  43.636258 -79.498509
# 118  43.636258 -79.498509
# 119  43.628841 -79.520999
# 120  43.628841 -79.520999
# 121  43.628841 -79.520999
# 122  43.667856 -79.532242
# 123  43.650943 -79.554724
# 124  43.650943 -79.554724
# 125  43.650943 -79.554724
# 126  43.643515 -79.577201
# 127  43.643515 -79.577201
# 128  43.756303 -79.565963
# 129  43.724766 -79.532242
# 130  43.706876 -79.518188
# 131  43.696319 -79.532242
# 132  43.688905 -79.554724
# 133  43.688905 -79.554724
# 134  43.739416 -79.588437
# 135  43.739416 -79.588437
# 136  43.739416 -79.588437
# 137  43.739416 -79.588437
# 138  43.706748 -79.594054
#
# [139 rows x 5 columns]

# %% [markdown]
# <b> Q3: cluster based on borough and show map </b>

# %%
#=============================select best k for clustering and assign Borough in the list to the cluster ===============================
df_withLL.dropna(axis=0,how='any',subset=['Latitude','Longitude'],inplace=True)
X=df_withLL.loc[:,['Borough','Latitude','Longitude']]
K_clusters = range(1,10)
kmeans = [KMeans(n_clusters=i) for i in K_clusters]
Y_axis = df_withLL[['Latitude']]
X_axis = df_withLL[['Longitude']]
score = [kmeans[i].fit(Y_axis).score(Y_axis) for i in range(len(kmeans))]
# Visualize
#plt.plot(K_clusters, score)
#plt.xlabel('Number of Clusters')
#plt.ylabel('Score')
#plt.title('Elbow Curve')
#plt.show()
#best_k=3
kmeans = KMeans(n_clusters = 3, init ='k-means++')
kmeans.fit(X[X.columns[1:3]]) # Compute k-means clustering.
X['cluster_label'] = kmeans.fit_predict(X[X.columns[1:3]])
centers = kmeans.cluster_centers_ # Coordinates of cluster centers.
labels = kmeans.predict(X[X.columns[1:3]]) # Labels of each point

#========================start creating map =========================================================
map = traffic_map = folium.Map(location=[43.7181552,-79.5184855], zoom_start=11)
colordict = {0: 'red', 1: 'green', 2: 'orange'}
for lat, lon, bor, label in zip(X['Latitude'], X['Longitude'],X['Borough'],X['cluster_label']):
    folium.Marker(
        location = [lat, lon],
        icon=folium.Icon(color=colordict[label])
        ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
